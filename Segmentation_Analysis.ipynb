# %%
#FriedMan Test
from scipy.stats import friedmanchisquare
import pandas as pd

df = pd.read_excel('/content/FreedMan.xlsx')

stat, p_value = friedmanchisquare(df['3DAttention_Rating'], df['3DMedSam_Rating'], df['ReconNet_Rating'], df['ResUNet_Rating'], df['VNet_Rating'])
print(f"Friedman Chi-Square Statistic: {stat}")
print(f"P-Value: {p_value}")
# Out:
# Friedman Chi-Square Statistic: 4.205128205128199
# P-Value: 0.3789559895897213

# %%
# HeatMap

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    "Question": [f"Q{i}" for i in range(1, 21)],
    "3DAttention": [2.83, 3.83, 3.5, 3.17, 3.5, 2.83, 3.00, 2.67, 2.33, 3.50,
                    2.6, 3.67, 2.33, 3.17, 3.67, 3.33, 4.17, 1.67, 4.2, 2.4],
    "3DMedSam": [2.17, 2.00, 1.5, 1.83, 2.00, 1.83, 2.67, 1.83, 1.67, 2.50,
                 1.8, 4.00, 2.33, 2.50, 3.50, 2.67, 3.33, 1.00, 4.20, 2.50],
    "ReconNet": [2.17, 2.67, 3.00, 2.67, 2.50, 2.33, 2.17, 2.00, 2.00, 2.33,
                 2.40, 3.67, 2.33, 3.33, 2.83, 3.00, 4.17, 1.67, 4.20, 2.50],
    "ResUNet": [2.33, 2.83, 2.50, 2.83, 3.00, 2.33, 2.33, 2.17, 1.50, 2.83,
                2.20, 2.83, 2.17, 2.67, 3.17, 2.33, 3.50, 1.00, 4.20, 2.50],
    "VNet": [2.67, 3.83, 3.50, 3.00, 1.83, 2.60, 2.67, 3.00, 2.67, 3.33,
             3.40, 3.50, 2.17, 3.33, 3.67, 3.17, 4.33, 1.83, 4.40, 2.40]
}

df = pd.DataFrame(data)
df = df.set_index("Question")
print(df)

plt.figure(figsize=(10, 8))
sns.set(font_scale=1.0)

ax = sns.heatmap(
    df.T,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    cbar_kws={'label': 'Average Clinical Score (0–5)'},
    linewidths=0.5
)

plt.title("Clinical Assessment Heatmap: AI Models vs. Ground Truth (20 Questions)", fontsize=14)
plt.xlabel("Question")
plt.ylabel("Model")

plt.xticks(rotation=45, ha='right')


plt.tight_layout()
plt.show()
# Out:
#           3DAttention  3DMedSam  ReconNet  ResUNet  VNet
# Question
# Q1               2.83      2.17      2.17     2.33  2.67
# Q2               3.83      2.00      2.67     2.83  3.83
# Q3               3.50      1.50      3.00     2.50  3.50
# Q4               3.17      1.83      2.67     2.83  3.00
# Q5               3.50      2.00      2.50     3.00  1.83
# Q6               2.83      1.83      2.33     2.33  2.60
# Q7               3.00      2.67      2.17     2.33  2.67
# Q8               2.67      1.83      2.00     2.17  3.00
# Q9               2.33      1.67      2.00     1.50  2.67
# Q10              3.50      2.50      2.33     2.83  3.33
# Q11              2.60      1.80      2.40     2.20  3.40
# Q12              3.67      4.00      3.67     2.83  3.50
# Q13              2.33      2.33      2.33     2.17  2.17
# Q14              3.17      2.50      3.33     2.67  3.33
# Q15              3.67      3.50      2.83     3.17  3.67
# ...

# %%
# Friedman Test for Q 6.1
from scipy.stats import friedmanchisquare
import pandas as pd

df = pd.read_excel('/content/6.1.xlsx')

stat, p_value = friedmanchisquare(df['3DAttention_Rating'], df['3DMedSam_Rating'], df['ReconNet_Rating'], df['ResUNet_Rating'], df['VNet_Rating'])
print(f"Friedman Chi-Square Statistic: {stat}")
print(f"P-Value: {p_value}")
# Out:
# Friedman Chi-Square Statistic: 2.1395348837209274
# P-Value: 0.7101129849875819

# %%
# Friedman Test for Q 6.2
from scipy.stats import friedmanchisquare
import pandas as pd

df = pd.read_excel('/content/6.2.xlsx')

stat, p_value = friedmanchisquare(df['3DAttention_Rating'], df['3DMedSam_Rating'], df['ReconNet_Rating'], df['ResUNet_Rating'], df['VNet_Rating'])
print(f"Friedman Chi-Square Statistic: {stat}")
print(f"P-Value: {p_value}")
# Out:
# Friedman Chi-Square Statistic: 3.802469135802467
# P-Value: 0.4333982583640874

# %%
# Friedman Test for Q 6.4
from scipy.stats import friedmanchisquare
import pandas as pd

df = pd.read_excel('/content/6.4.xlsx')

stat, p_value = friedmanchisquare(df['3DAttention_Rating'], df['3DMedSam_Rating'], df['ReconNet_Rating'], df['ResUNet_Rating'], df['VNet_Rating'])
print(f"Friedman Chi-Square Statistic: {stat}")
print(f"P-Value: {p_value}")
# Out:
# Friedman Chi-Square Statistic: 1.7142857142857144
# P-Value: 0.7881209991143356
